# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = {'A':[1,2,3], 'B':[4,5,6]}
df = pd.DataFrame(data)
print(df)
X = df.iloc[:,:].values
print(X)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# [[1 4]
#  [2 5]
#  [3 6]]

# %% [markdown]
# ## Bar Plot

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]

col= ["blue","black","gold","orange"]
plt.bar(x,y,width=0.2,color = col,align="center",edgecolor = "red",linewidth = 2,linestyle = "dotted",alpha = 0.7,label = "titan") # alpha parameter is for color of the fillings inside

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")
plt.legend(loc= "best")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z= [20,30,40,50]
p = np.arange(len(x))  
width = 0.2
p1 = [j+width for j in p]

plt.bar(p,y,width,color = "red",label = "titan") # alpha parameter is for color of the fillings inside
plt.bar(p1,z,width,color = "aqua",label = "titan1")

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")

plt.xticks(p+width/2,x,rotation = 20)
plt.legend()
plt.show()
print(p)
print(p1)
# Out:
# [0 1 2 3]
# [0.2, 1.2, 2.2, 3.2]

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z= [20,30,40,50]
p = np.arange(len(x))  
width = 0.2
p1 = [j+width for j in p]

plt.barh(x,y,width,color = "red",label = "titan") # alpha parameter is for color of the fillings inside
plt.barh(x,z,width,color = "aqua",label = "titan1")

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")


plt.legend()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
day = [1,2,3,4,5,6,7]
num = [2,3,1,4,5,3,6]
col = ['blue', 'red', 'green','magenta','cyan','purple','black']
plt.scatter(day,num,c = col,s = 30)
plt.xlabel("Day")
plt.ylabel("Number")
plt.show()

# %%
day = [1,2,3,4,5,6,7]
num = [2,3,1,4,5,3,6]
col = ['blue', 'red', 'green','magenta','cyan','purple','black']
# plt.scatter(day,num,s = 50,c=col,alpha=0.6,marker="*",edgecolors="black",linewidth=2,cmap="viridis")
plt.scatter(day,num,s = 50,c=col,alpha=0.6,marker="*",edgecolors="black",linewidth=2)
plt.plot(day,num)
t=plt.colorbar()
t.set_label("Color Bar")
plt.xlabel("Day")
plt.ylabel("Number")
plt.show()

# %% [markdown]
# ## Histogram Plot

# %%
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [19 32 33 36 28 30 13 46 37 26 58 22 55 51 59 54 13 38 38 28 57 48 32 39
#  49 53 50 48 52 48 31 45 52 55 27 14 34 18 17 29 20 49 48 22 40 10 22 52
#  21 48]

# %%
y=[]
for i in x:
    y.append(i)

y=np.array(y)
print(y)
# Out:
# [19 32 33 36 28 30 13 46 37 26 58 22 55 51 59 54 13 38 38 28 57 48 32 39
#  49 53 50 48 52 48 31 45 52 55 27 14 34 18 17 29 20 49 48 22 40 10 22 52
#  21 48]

# %%
plt.hist(y,edgecolor="black",bins =[10,20,30,40,50,60],align='mid',histtype='bar',orientation='vertical',rwidth=1,log=True,label="python")
# plt.hist(y,edgecolor="black",bins =5,align='mid',histtype='bar',orientation='vertical',rwidth=1,log=True,label="python")
plt.axvline(45,color="green",label = "Axis")

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.legend()
plt.show()

# %%
plt.hist(y,edgecolor="black",range=(0,100))

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.show()

# %%
plt.hist(y,edgecolor="black",range=(0,100),cumulative=-1)

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.show()

# %%
df = pd.read_csv('housing.csv')
print(df.isnull().sum())
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
x = df['total_bedrooms'].mean()
print(x)
# Out:
# 537.8705525375618

# %%
df['total_bedrooms'].fillna(x,inplace=True)

# %%
print(df.isnull().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    787.000000    280.000000       2.563400
# 50%        438.000000   1166.000000    409.000000       3.534800
# 75%        643.250000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
df = df.rename({'longitude':'long', 'latitude':'lat'},axis = 1)
df
# Out:
#          long    lat  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23  37.88                41.0        880.0           129.0
# 1     -122.22  37.86                21.0       7099.0          1106.0
# 2     -122.24  37.85                52.0       1467.0           190.0
# 3     -122.25  37.85                52.0       1274.0           235.0
# 4     -122.25  37.85                52.0       1627.0           280.0
# ...       ...    ...                 ...          ...             ...
# 20635 -121.09  39.48                25.0       1665.0           374.0
# 20636 -121.21  39.49                18.0        697.0           150.0
# 20637 -121.22  39.43                17.0       2254.0           485.0
# 20638 -121.32  39.43                18.0       1860.0           409.0
# 20639 -121.24  39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.head(15)
# Out:
#       long    lat  housing_median_age  total_rooms  total_bedrooms  \
# 0  -122.23  37.88                41.0        880.0           129.0
# 1  -122.22  37.86                21.0       7099.0          1106.0
# 2  -122.24  37.85                52.0       1467.0           190.0
# 3  -122.25  37.85                52.0       1274.0           235.0
# 4  -122.25  37.85                52.0       1627.0           280.0
# 5  -122.25  37.85                52.0        919.0           213.0
# 6  -122.25  37.84                52.0       2535.0           489.0
# 7  -122.25  37.84                52.0       3104.0           687.0
# 8  -122.26  37.84                42.0       2555.0           665.0
# 9  -122.25  37.84                52.0       3549.0           707.0
# 10 -122.26  37.85                52.0       2202.0           434.0
# 11 -122.26  37.85                52.0       3503.0           752.0
# 12 -122.26  37.85                52.0       2491.0           474.0
# 13 -122.26  37.84                52.0        696.0           191.0
# 14 -122.26  37.85                52.0       2643.0           626.0
#
#     population  households  median_income  median_house_value ocean_proximity
# 0        322.0       126.0         8.3252            452600.0        NEAR BAY
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2        496.0       177.0         7.2574            352100.0        NEAR BAY
# 3        558.0       219.0         5.6431            341300.0        NEAR BAY
# 4        565.0       259.0         3.8462            342200.0        NEAR BAY
# 5        413.0       193.0         4.0368            269700.0        NEAR BAY
# 6       1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7       1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8       1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9       1551.0       714.0         3.6912            261100.0        NEAR BAY
# 10       910.0       402.0         3.2031            281500.0        NEAR BAY
# 11      1504.0       734.0         3.2705            241800.0        NEAR BAY
# 12      1098.0       468.0         3.0750            213500.0        NEAR BAY
# 13       345.0       174.0         2.6736            191300.0        NEAR BAY
# 14      1212.0       620.0         1.9167            159200.0        NEAR BAY

# %%
df = df.sort_index()

# %%
df
# Out:
#          long    lat  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23  37.88                41.0        880.0           129.0
# 1     -122.22  37.86                21.0       7099.0          1106.0
# 2     -122.24  37.85                52.0       1467.0           190.0
# 3     -122.25  37.85                52.0       1274.0           235.0
# 4     -122.25  37.85                52.0       1627.0           280.0
# ...       ...    ...                 ...          ...             ...
# 20635 -121.09  39.48                25.0       1665.0           374.0
# 20636 -121.21  39.49                18.0        697.0           150.0
# 20637 -121.22  39.43                17.0       2254.0           485.0
# 20638 -121.32  39.43                18.0       1860.0           409.0
# 20639 -121.24  39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df2 = df.sort_values(by='lat')
df2
# Out:
#          long    lat  housing_median_age  total_rooms  total_bedrooms  \
# 14762 -117.04  32.54                 7.0        938.0           297.0
# 14761 -117.06  32.55                 5.0       3223.0           940.0
# 14784 -117.09  32.55                 8.0       6533.0          1217.0
# 14757 -117.04  32.55                15.0       2206.0           648.0
# 14756 -116.97  32.56                23.0       1262.0           294.0
# ...       ...    ...                 ...          ...             ...
# 18825 -122.33  41.86                19.0       3599.0           695.0
# 1864  -123.83  41.88                18.0       1504.0           357.0
# 1860  -124.16  41.92                19.0       1668.0           324.0
# 1859  -124.14  41.95                21.0       2696.0           578.0
# 18828 -122.64  41.95                18.0       1867.0           424.0
#
#        population  households  median_income  median_house_value  \
# 14762      1187.0       282.0         1.2667             67500.0
# 14761      3284.0       854.0         1.4384            108800.0
# 14784      4797.0      1177.0         3.9583            144400.0
# 14757      2511.0       648.0         1.6348             93200.0
# 14756      5176.0       275.0         2.5625            153300.0
# ...           ...         ...            ...                 ...
# 18825      1572.0       601.0         2.2340             58600.0
# 1864        660.0       258.0         3.1300            116700.0
# 1860        841.0       283.0         2.1336             75000.0
# 1859       1208.0       494.0         2.2750            122400.0
# 18828       802.0       314.0         1.8242             53500.0
#
#       ocean_proximity
# 14762      NEAR OCEAN
# 14761      NEAR OCEAN
# 14784      NEAR OCEAN
# 14757      NEAR OCEAN
# 14756      NEAR OCEAN
# ...               ...
# 18825          INLAND
# 1864        <1H OCEAN
# 1860       NEAR OCEAN
# 1859       NEAR OCEAN
# 18828          INLAND
#
# [20640 rows x 10 columns]

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
tf= df[df['population']==df['population'].max()]
tf
# print(tf['housing_median_age'])
# Out:
#          long    lat  housing_median_age  total_rooms  total_bedrooms  \
# 15360 -117.42  33.35                14.0      25135.0          4819.0
#
#        population  households  median_income  median_house_value  \
# 15360     35682.0      4769.0         2.5729            134400.0
#
#       ocean_proximity
# 15360       <1H OCEAN

# %%
df.iloc[4500]
# Out:
# long                    -118.21
# lat                       34.05
# housing_median_age         28.0
# total_rooms               950.0
# total_bedrooms            357.0
# population               1485.0
# households                345.0
# median_income            1.9271
# median_house_value     136400.0
# ocean_proximity       <1H OCEAN
# Name: 4500, dtype: object

# %%
data_types = df.dtypes
print(data_types)
# Out:
# long                  float64
# lat                   float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.corr()
# Out:
# /var/folders/21/yhy2dhmx219b7cbcq243hmwc0000gn/T/ipykernel_12121/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         long       lat  housing_median_age  total_rooms  \
# long                1.000000 -0.924664           -0.108197     0.044568
# lat                -0.924664  1.000000            0.011173    -0.036100
# housing_median_age -0.108197  0.011173            1.000000    -0.361262
# total_rooms         0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms      0.069260 -0.066658           -0.318998     0.927253
# population          0.099773 -0.108785           -0.296244     0.857126
# households          0.055310 -0.071035           -0.302916     0.918484
# median_income      -0.015176 -0.079809           -0.119034     0.198050
# median_house_value -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# long                      0.069260    0.099773    0.055310      -0.015176
# lat                      -0.066658   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.318998   -0.296244   -0.302916      -0.119034
# total_rooms               0.927253    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.873910    0.974725      -0.007682
# population                0.873910    1.000000    0.907222       0.004834
# households                0.974725    0.907222    1.000000       0.013033
# median_income            -0.007682    0.004834    0.013033       1.000000
# median_house_value        0.049454   -0.024650    0.065843       0.688075
#
#                     median_house_value
# long                         -0.045967
# lat                          -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049454
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %%
df.plot()
plt.show()

# %%
df.plot(kind="scatter",x = 'lat',y ='population')
# Out:
# <Axes: xlabel='lat', ylabel='population'>

# %%
df
# Out:
#          long    lat  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23  37.88                41.0        880.0           129.0
# 1     -122.22  37.86                21.0       7099.0          1106.0
# 2     -122.24  37.85                52.0       1467.0           190.0
# 3     -122.25  37.85                52.0       1274.0           235.0
# 4     -122.25  37.85                52.0       1627.0           280.0
# ...       ...    ...                 ...          ...             ...
# 20635 -121.09  39.48                25.0       1665.0           374.0
# 20636 -121.21  39.49                18.0        697.0           150.0
# 20637 -121.22  39.43                17.0       2254.0           485.0
# 20638 -121.32  39.43                18.0       1860.0           409.0
# 20639 -121.24  39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df['housing_median_age'].plot(kind="hist",bins=10,cumulative = True)
plt.show()

# %%
df
# Out:
#          long    lat  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23  37.88                41.0        880.0           129.0
# 1     -122.22  37.86                21.0       7099.0          1106.0
# 2     -122.24  37.85                52.0       1467.0           190.0
# 3     -122.25  37.85                52.0       1274.0           235.0
# 4     -122.25  37.85                52.0       1627.0           280.0
# ...       ...    ...                 ...          ...             ...
# 20635 -121.09  39.48                25.0       1665.0           374.0
# 20636 -121.21  39.49                18.0        697.0           150.0
# 20637 -121.22  39.43                17.0       2254.0           485.0
# 20638 -121.32  39.43                18.0       1860.0           409.0
# 20639 -121.24  39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
# df.drop(columns='ocean_proximity')
