# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('educ_inc.csv')

# %%
df
# Out:
#              Year        Age  Gender          Educational Attainment  \
# 0     1/1/08 0:00   00 to 17    Male  College, less than 4-yr degree
# 1     1/1/08 0:00   00 to 17  Female  College, less than 4-yr degree
# 2     1/1/08 0:00  65 to 80+    Male  College, less than 4-yr degree
# 3     1/1/08 0:00  65 to 80+  Female          No high school diploma
# 4     1/1/08 0:00   00 to 17  Female          No high school diploma
# ...           ...        ...     ...                             ...
# 1021  1/1/14 0:00   18 to 64  Female       High school or equivalent
# 1022  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
# 1023  1/1/14 0:00   18 to 64  Female          No high school diploma
# 1024  1/1/14 0:00   18 to 64  Female     Bachelor's degree or higher
# 1025  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# ...

# %%
df[df['Year']>='']
# Out:
#              Year        Age  Gender          Educational Attainment  \
# 0     1/1/08 0:00   00 to 17    Male  College, less than 4-yr degree
# 1     1/1/08 0:00   00 to 17  Female  College, less than 4-yr degree
# 2     1/1/08 0:00  65 to 80+    Male  College, less than 4-yr degree
# 3     1/1/08 0:00  65 to 80+  Female          No high school diploma
# 4     1/1/08 0:00   00 to 17  Female          No high school diploma
# ...           ...        ...     ...                             ...
# 1021  1/1/14 0:00   18 to 64  Female       High school or equivalent
# 1022  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
# 1023  1/1/14 0:00   18 to 64  Female          No high school diploma
# 1024  1/1/14 0:00   18 to 64  Female     Bachelor's degree or higher
# 1025  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# ...

# %%
df['Year'] = pd.to_datetime(df['Year'])
print(df)
df['Y'] = df['Year'].dt.year
# Out:
#            Year        Age  Gender          Educational Attainment  \
# 0    2008-01-01   00 to 17    Male  College, less than 4-yr degree
# 1    2008-01-01   00 to 17  Female  College, less than 4-yr degree
# 2    2008-01-01  65 to 80+    Male  College, less than 4-yr degree
# 3    2008-01-01  65 to 80+  Female          No high school diploma
# 4    2008-01-01   00 to 17  Female          No high school diploma
# ...         ...        ...     ...                             ...
# 1021 2014-01-01   18 to 64  Female       High school or equivalent
# 1022 2014-01-01   18 to 64    Male     Bachelor's degree or higher
# 1023 2014-01-01   18 to 64  Female          No high school diploma
# 1024 2014-01-01   18 to 64  Female     Bachelor's degree or higher
# 1025 2014-01-01   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# ...

# %%
df
# Out:
#            Year        Age  Gender          Educational Attainment  \
# 0    2008-01-01   00 to 17    Male  College, less than 4-yr degree
# 1    2008-01-01   00 to 17  Female  College, less than 4-yr degree
# 2    2008-01-01  65 to 80+    Male  College, less than 4-yr degree
# 3    2008-01-01  65 to 80+  Female          No high school diploma
# 4    2008-01-01   00 to 17  Female          No high school diploma
# ...         ...        ...     ...                             ...
# 1021 2014-01-01   18 to 64  Female       High school or equivalent
# 1022 2014-01-01   18 to 64    Male     Bachelor's degree or higher
# 1023 2014-01-01   18 to 64  Female          No high school diploma
# 1024 2014-01-01   18 to 64  Female     Bachelor's degree or higher
# 1025 2014-01-01   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count     Y
# 0     C: 10,000 to 14,999              1304  2008
# 1       B: 5,000 to 9,999              1565  2008
# ...

# %%
df.groupby(by = 'Educational Attainment')['Population Count'].sum()
# Out:
# Educational Attainment
# Bachelor's degree or higher       54617676
# College, less than 4-yr degree    52137494
# High school or equivalent         42942926
# No high school diploma            40668871
# Name: Population Count, dtype: int64

# %%
df.groupby(by = 'Educational Attainment')

# %%
type(df.iloc[1,1])
# Out:
# str

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Age'] = le.fit_transform(df['Age'])

# %%
df
# Out:
#            Year  Age  Gender          Educational Attainment  \
# 0    2008-01-01    0    Male  College, less than 4-yr degree
# 1    2008-01-01    0  Female  College, less than 4-yr degree
# 2    2008-01-01    2    Male  College, less than 4-yr degree
# 3    2008-01-01    2  Female          No high school diploma
# 4    2008-01-01    0  Female          No high school diploma
# ...         ...  ...     ...                             ...
# 1021 2014-01-01    1  Female       High school or equivalent
# 1022 2014-01-01    1    Male     Bachelor's degree or higher
# 1023 2014-01-01    1  Female          No high school diploma
# 1024 2014-01-01    1  Female     Bachelor's degree or higher
# 1025 2014-01-01    1    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count     Y
# 0     C: 10,000 to 14,999              1304  2008
# 1       B: 5,000 to 9,999              1565  2008
# 2           A: 0 to 4,999              1923  2008
# ...

# %%
df['Age']
# Out:
# 0       0
# 1       0
# 2       2
# 3       2
# 4       0
#        ..
# 1021    1
# 1022    1
# 1023    1
# 1024    1
# 1025    1
# Name: Age, Length: 1026, dtype: int64

# %%
tf = df[df['Age']>=1]

# %%
tf
# Out:
#            Year  Age  Gender          Educational Attainment  \
# 2    2008-01-01    2    Male  College, less than 4-yr degree
# 3    2008-01-01    2  Female          No high school diploma
# 9    2008-01-01    1  Female          No high school diploma
# 11   2008-01-01    2    Male          No high school diploma
# 16   2008-01-01    2  Female          No high school diploma
# ...         ...  ...     ...                             ...
# 1021 2014-01-01    1  Female       High school or equivalent
# 1022 2014-01-01    1    Male     Bachelor's degree or higher
# 1023 2014-01-01    1  Female          No high school diploma
# 1024 2014-01-01    1  Female     Bachelor's degree or higher
# 1025 2014-01-01    1    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count     Y
# 2           A: 0 to 4,999              1923  2008
# 3      H: 75,000 and over              1981  2008
# 9      H: 75,000 and over              4233  2008
# ...

# %%
tf2 = pd.DataFrame(tf.groupby(by = 'Educational Attainment')['Population Count'].sum())

# %%
type(tf2)
# Out:
# pandas.core.frame.DataFrame

# %%
tf2
# Out:
#                                 Population Count
# Educational Attainment
# Bachelor's degree or higher             54603003
# College, less than 4-yr degree          52045952
# High school or equivalent               42828045
# No high school diploma                  31102348

# %%
sum = tf2['Population Count'].sum()
print(sum)
# Out:
# 180579348

# %%
tf2['Percentage']= tf2['Population Count']/sum
tf2
# Out:
#                                 Population Count  Percentage
# Educational Attainment
# Bachelor's degree or higher             54603003    0.302377
# College, less than 4-yr degree          52045952    0.288217
# High school or equivalent               42828045    0.237170
# No high school diploma                  31102348    0.172236

# %%
contingency_table = pd.pivot_table(df, index='Educational Attainment', columns='Personal Income', aggfunc='count', fill_value=0)
print(contingency_table)
# Out:
#                                          Age                    \
# Personal Income                A: 0 to 4,999 B: 5,000 to 9,999
# Educational Attainment
# Bachelor's degree or higher               30                28
# College, less than 4-yr degree            36                35
# High school or equivalent                 35                36
# No high school diploma                    42                42
#
#                                                                         \
# Personal Income                C: 10,000 to 14,999 D: 15,000 to 24,999
# Educational Attainment
# Bachelor's degree or higher                     29                  30
# College, less than 4-yr degree                  34                  36
# High school or equivalent                       33                  32
# No high school diploma                          42                  39
#
#                                                                         \
# ...

# %%
df
# Out:
#            Year  Age  Gender          Educational Attainment  \
# 0    2008-01-01    0    Male  College, less than 4-yr degree
# 1    2008-01-01    0  Female  College, less than 4-yr degree
# 2    2008-01-01    2    Male  College, less than 4-yr degree
# 3    2008-01-01    2  Female          No high school diploma
# 4    2008-01-01    0  Female          No high school diploma
# ...         ...  ...     ...                             ...
# 1021 2014-01-01    1  Female       High school or equivalent
# 1022 2014-01-01    1    Male     Bachelor's degree or higher
# 1023 2014-01-01    1  Female          No high school diploma
# 1024 2014-01-01    1  Female     Bachelor's degree or higher
# 1025 2014-01-01    1    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count     Y
# 0     C: 10,000 to 14,999              1304  2008
# 1       B: 5,000 to 9,999              1565  2008
# 2           A: 0 to 4,999              1923  2008
# ...

# %%
df['Educational Attainment'].value_counts()
# Out:
# No high school diploma            287
# College, less than 4-yr degree    258
# High school or equivalent         250
# Bachelor's degree or higher       231
# Name: Educational Attainment, dtype: int64

# %%
x = pd.DataFrame(df[df['Educational Attainment']=='No high school diploma'])

# %%
x
# Out:
#            Year  Age  Gender  Educational Attainment      Personal Income  \
# 3    2008-01-01    2  Female  No high school diploma   H: 75,000 and over
# 4    2008-01-01    0  Female  No high school diploma  D: 15,000 to 24,999
# 5    2008-01-01    0    Male  No high school diploma  F: 35,000 to 49,999
# 6    2008-01-01    0    Male  No high school diploma  E: 25,000 to 34,999
# 8    2008-01-01    0    Male  No high school diploma  D: 15,000 to 24,999
# ...         ...  ...     ...                     ...                  ...
# 1000 2014-01-01    1    Male  No high school diploma        A: 0 to 4,999
# 1007 2014-01-01    1    Male  No high school diploma  D: 15,000 to 24,999
# 1018 2014-01-01    0    Male  No high school diploma        A: 0 to 4,999
# 1019 2014-01-01    0  Female  No high school diploma        A: 0 to 4,999
# 1023 2014-01-01    1  Female  No high school diploma        A: 0 to 4,999
#
#       Population Count     Y
# 3                 1981  2008
# ...

# %%
df
# Out:
#            Year  Age  Gender          Educational Attainment  \
# 0    2008-01-01    0    Male  College, less than 4-yr degree
# 1    2008-01-01    0  Female  College, less than 4-yr degree
# 2    2008-01-01    2    Male  College, less than 4-yr degree
# 3    2008-01-01    2  Female          No high school diploma
# 4    2008-01-01    0  Female          No high school diploma
# ...         ...  ...     ...                             ...
# 1021 2014-01-01    1  Female       High school or equivalent
# 1022 2014-01-01    1    Male     Bachelor's degree or higher
# 1023 2014-01-01    1  Female          No high school diploma
# 1024 2014-01-01    1  Female     Bachelor's degree or higher
# 1025 2014-01-01    1    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count     Y
# 0     C: 10,000 to 14,999              1304  2008
# 1       B: 5,000 to 9,999              1565  2008
# 2           A: 0 to 4,999              1923  2008
# ...

# %%
y = pd.DataFrame(df[df['Educational Attainment']== "Bachelor's degree or higher"])

# %%
y
# Out:
#            Year  Age  Gender       Educational Attainment  \
# 22   2008-01-01    2  Female  Bachelor's degree or higher
# 31   2008-01-01    2    Male  Bachelor's degree or higher
# 32   2008-01-01    2    Male  Bachelor's degree or higher
# 45   2008-01-01    2  Female  Bachelor's degree or higher
# 46   2008-01-01    2  Female  Bachelor's degree or higher
# ...         ...  ...     ...                          ...
# 1015 2014-01-01    1  Female  Bachelor's degree or higher
# 1020 2014-01-01    1  Female  Bachelor's degree or higher
# 1022 2014-01-01    1    Male  Bachelor's degree or higher
# 1024 2014-01-01    1  Female  Bachelor's degree or higher
# 1025 2014-01-01    1    Male  Bachelor's degree or higher
#
#           Personal Income  Population Count     Y
# 22          A: 0 to 4,999             12915  2008
# 31          A: 0 to 4,999             25141  2008
# 32      B: 5,000 to 9,999             27004  2008
# 45    D: 15,000 to 24,999             42390  2008
# ...

# %%
obj= x.groupby(by = 'Personal Income')['Population Count'].sum()

# %%
obj
# Out:
# Personal Income
# A: 0 to 4,999          16959363
# B: 5,000 to 9,999       5106194
# C: 10,000 to 14,999     5516889
# D: 15,000 to 24,999     6777351
# E: 25,000 to 34,999     3055748
# F: 35,000 to 49,999     1939568
# G: 50,000 to 74,999      930115
# H: 75,000 and over       383643
# Name: Population Count, dtype: int64

# %%
obj1 = y.groupby(by = 'Personal Income')['Population Count'].sum()

# %%
obj1
# Out:
# Personal Income
# A: 0 to 4,999           3159007
# B: 5,000 to 9,999       2252588
# C: 10,000 to 14,999     2683138
# D: 15,000 to 24,999     5156919
# E: 25,000 to 34,999     4945861
# F: 35,000 to 49,999     7328963
# G: 50,000 to 74,999    10795902
# H: 75,000 and over     18295298
# Name: Population Count, dtype: int64

# %%
x_axis = obj.index.to_numpy

# %%
x_axis
# Out:
# <bound method IndexOpsMixin.to_numpy of Index(['A: 0 to 4,999', 'B: 5,000 to 9,999', 'C: 10,000 to 14,999',
#        'D: 15,000 to 24,999', 'E: 25,000 to 34,999', 'F: 35,000 to 49,999',
#        'G: 50,000 to 74,999', 'H: 75,000 and over'],
#       dtype='object', name='Personal Income')>

# %%
type(x_axis)
# Out:
# method

# %%
plt.bar(x=x_axis,y = obj.values,height = 0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2458, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2457 try:
# -> 2458     left = x - width / 2
#    2459 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'method' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 plt.bar(x=x_axis,y = obj.values,height = 0.5)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/matplotlib/pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
# ...

# %%
import pandas as pd

# Sample data
data = [10, 15, 20, 25, 30, 35, 40, 45, 50, 1000]  # Positively skewed data

# Create a pandas Series
series = pd.Series(data)

# Calculate skewness
skewness = series.skew()

print("Skewness:", skewness)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot()

# %%
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/2975678/5123193/babies.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20231017%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20231017T040159Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...', index_col='case')
df
# Out:
#       bwt  gestation  parity   age  height  weight  smoke
# case
# 1     120      284.0       0  27.0    62.0   100.0    0.0
# 2     113      282.0       0  33.0    64.0   135.0    0.0
# 3     128      279.0       0  28.0    64.0   115.0    1.0
# 4     123        NaN       0  36.0    69.0   190.0    0.0
# 5     108      282.0       0  23.0    67.0   125.0    1.0
# ...   ...        ...     ...   ...     ...     ...    ...
# 1232  113      275.0       1  27.0    60.0   100.0    0.0
# 1233  128      265.0       0  24.0    67.0   120.0    0.0
# 1234  130      291.0       0  30.0    65.0   150.0    1.0
# 1235  125      281.0       1  21.0    65.0   110.0    0.0
# 1236  117      297.0       0  38.0    65.0   129.0    0.0
#
# [1236 rows x 7 columns]
