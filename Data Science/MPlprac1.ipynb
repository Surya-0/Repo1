# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = {'A':[1,2,3], 'B':[4,5,6]}
df = pd.DataFrame(data)
print(df)
X = df.iloc[:,:].values
print(X)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# [[1 4]
#  [2 5]
#  [3 6]]

# %% [markdown]
# ## Bar Plot

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]

col= ["blue","black","gold","orange"]
plt.bar(x,y,width=0.2,color = col,align="center",edgecolor = "red",linewidth = 2,linestyle = "dotted",alpha = 0.7,label = "titan") # alpha parameter is for color of the fillings inside

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")
plt.legend(loc= "best")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z= [20,30,40,50]
p = np.arange(len(x))  
print(p)
width = 0.2
p1 = [j+width for j in p]

plt.bar(p,y,width,color = "red",label = "titan") # alpha parameter is for color of the fillings inside
plt.bar(p1,z,width,color = "aqua",label = "titan1")

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")

plt.xticks(p+width/2,x,rotation = 20)
plt.legend()
plt.show()
print(p)
print(p1)
# Out:
# [0 1 2 3]
# [0 1 2 3]
# [0.2, 1.2, 2.2, 3.2]

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z= [20,30,40,50]
p = np.arange(len(x))  
width = 0.2
p1 = [j+width for j in p]

plt.barh(x,y,width,color = "red",label = "titan") # alpha parameter is for color of the fillings inside
plt.barh(x,z,width,color = "aqua",label = "titan1")

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")


plt.legend()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
day = [1,2,3,4,5,6,7]
num = [2,3,1,4,5,3,6]
col = ['blue', 'red', 'green','magenta','cyan','purple','black']
plt.scatter(day,num,c = col,s = 30)
plt.xlabel("Day")
plt.ylabel("Number")
plt.show()

# %%
day = [1,2,3,4,5,6,7]
num = [2,3,1,4,5,3,6]
col = ['blue', 'red', 'green','magenta','cyan','purple','black']
# plt.scatter(day,num,s = 50,c=col,alpha=0.6,marker="*",edgecolors="black",linewidth=2,cmap="viridis")
plt.scatter(day,num,s = 50,c=col,alpha=0.6,marker="*",edgecolors="black",linewidth=2)
plt.plot(day,num)
t=plt.colorbar()
t.set_label("Color Bar")
plt.xlabel("Day")
plt.ylabel("Number")
plt.show()

# %% [markdown]
# ## Histogram Plot

# %%
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [20 58 25 49 49 21 14 41 31 58 12 20 10 48 15 57 17 21 34 58 51 29 32 31
#  11 52 10 27 17 42 25 51 45 58 40 16 34 33 38 30 21 36 14 34 34 40 59 34
#  23 29]

# %%
y=[]
for i in x:
    y.append(i)

y=np.array(y)
print(y)
# Out:
# [20 58 25 49 49 21 14 41 31 58 12 20 10 48 15 57 17 21 34 58 51 29 32 31
#  11 52 10 27 17 42 25 51 45 58 40 16 34 33 38 30 21 36 14 34 34 40 59 34
#  23 29]

# %%
plt.hist(y,edgecolor="black",bins =[10,20,30,40,50,60],align='mid',histtype='bar',orientation='vertical',rwidth=1,log=True,label="python")
# plt.hist(y,edgecolor="black",bins =5,align='mid',histtype='bar',orientation='vertical',rwidth=1,log=True,label="python")
plt.axvline(45,color="green",label = "Axis")

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.legend()
plt.show()

# %%
plt.hist(y,edgecolor="black",range=(0,100))

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.show()

# %%
plt.hist(y,edgecolor="black",range=(0,100),cumulative=-1)

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.show()

# %%
df = pd.read_csv('housing.csv')
print(df.isnull().sum())
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
x = df['total_bedrooms'].mean()
print(x)
# Out:
# 537.8705525375618

# %%
y = df.to_numpy()
print(type(y))
# Out:
# <class 'numpy.ndarray'>

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df['total_bedrooms'].fillna(x,inplace=True)

# %%
print(df.isnull().sum())

# %%
df

# %%
df.describe()

# %%
df = df.rename({'longitude':'long', 'latitude':'lat'},axis = 1)
df

# %%
df.head(15)

# %%
df = df.sort_index()

# %%
df

# %%
df2 = df.sort_values(by='lat')
df2

# %%
df['ocean_proximity'].value_counts()

# %%
df.duplicated().sum()

# %%
tf= df[df['population']==df['population'].max()]
tf
# print(tf['housing_median_age'])

# %%
df.iloc[4500]

# %%
data_types = df.dtypes
print(data_types)

# %%
df.shape

# %%
df.corr()

# %%
df.plot()
plt.show()

# %%
df.plot(kind="scatter",x = 'lat',y ='population')

# %%
df

# %%
df['housing_median_age'].plot(kind="hist",bins=10,cumulative = True)
plt.show()

# %%
df

# %%
# df.drop(columns='ocean_proximity')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://github.com/flaviovdf/evcomp2018/raw/master/data/nc-est2015-agesex-res.csv')
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 1      0    1        3978070            3978090          3957888
# 2      0    2        4096929            4096939          4090862
# 3      0    3        4119040            4119051          4111920
# 4      0    4        4063170            4063186          4077551
# ..   ...  ...            ...                ...              ...
# 301    2   97          53582              53605            54118
# 302    2   98          36641              36675            37532
# 303    2   99          26193              26214            26074
# 304    2  100          44202              44246            45058
# 305    2  999      156964212          156969328        157258820
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0            3963087          3926540          3931141          3949775
# 1            3966551          3977939          3942872          3949776
# 2            3971565          3980095          3992720          3959664
# 3            4102470          3983157          3992734          4007079
# 4            4122294          4112849          3994449          4005716
# ..               ...              ...              ...              ...
# 301            57159            59533            61255            62779
# 302            40116            42857            44359            46208
# 303            27030            29320            31112            32517
# 304            47556            50661            53902            58008
# 305        158427085        159581546        160720625        161952064
#
#      POPESTIMATE2015
# 0            3978038
# 1            3968564
# 2            3966583
# 3            3974061
# 4            4020035
# ..               ...
# 301            69285
# 302            47272
# 303            34064
# 304            61886
# 305        163189523
#
# [306 rows x 10 columns]

# %%
df.size
# Out:
# 3060

# %%
df.describe()
# Out:
#               SEX         AGE  CENSUS2010POP  ESTIMATESBASE2010  \
# count  306.000000  306.000000   3.060000e+02       3.060000e+02
# mean     1.000000   59.303922   4.035889e+06       4.036054e+06
# std      0.817834   98.060950   2.140881e+07       2.140968e+07
# min      0.000000    0.000000   6.073000e+03       6.075000e+03
# 25%      0.000000   25.000000   9.987065e+05       9.987415e+05
# 50%      1.000000   50.500000   2.045286e+06       2.045342e+06
# 75%      2.000000   76.000000   2.304370e+06       2.304525e+06
# max      2.000000  999.000000   3.087455e+08       3.087581e+08
#
#        POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# count     3.060000e+02     3.060000e+02     3.060000e+02     3.060000e+02
# mean      4.043750e+06     4.074756e+06     4.105917e+06     4.136306e+06
# std       2.145038e+07     2.161430e+07     2.177900e+07     2.193965e+07
# min       6.104000e+03     6.606000e+03     7.459000e+03     8.159000e+03
# 25%       1.010409e+06     1.045244e+06     1.073482e+06     1.121864e+06
# 50%       2.047912e+06     2.051284e+06     2.054609e+06     2.050533e+06
# 75%       2.304142e+06     2.321829e+06     2.335085e+06     2.349450e+06
# max       3.093469e+08     3.117189e+08     3.141026e+08     3.164274e+08
#
#        POPESTIMATE2014  POPESTIMATE2015
# count     3.060000e+02     3.060000e+02
# mean      4.168724e+06     4.201553e+06
# std       2.211105e+07     2.228462e+07
# min       8.951000e+03     9.577000e+03
# 25%       1.156036e+06     1.162476e+06
# 50%       2.060284e+06     2.062285e+06
# 75%       2.387392e+06     2.415332e+06
# max       3.189074e+08     3.214188e+08

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 1      0    1        3978070            3978090          3957888
# 2      0    2        4096929            4096939          4090862
# 3      0    3        4119040            4119051          4111920
# 4      0    4        4063170            4063186          4077551
# ..   ...  ...            ...                ...              ...
# 301    2   97          53582              53605            54118
# 302    2   98          36641              36675            37532
# 303    2   99          26193              26214            26074
# 304    2  100          44202              44246            45058
# 305    2  999      156964212          156969328        157258820
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0            3963087          3926540          3931141          3949775
# 1            3966551          3977939          3942872          3949776
# 2            3971565          3980095          3992720          3959664
# 3            4102470          3983157          3992734          4007079
# 4            4122294          4112849          3994449          4005716
# ..               ...              ...              ...              ...
# 301            57159            59533            61255            62779
# 302            40116            42857            44359            46208
# 303            27030            29320            31112            32517
# 304            47556            50661            53902            58008
# 305        158427085        159581546        160720625        161952064
#
#      POPESTIMATE2015
# 0            3978038
# 1            3968564
# 2            3966583
# 3            3974061
# 4            4020035
# ..               ...
# 301            69285
# 302            47272
# 303            34064
# 304            61886
# 305        163189523
#
# [306 rows x 10 columns]

# %%
df = df.rename(columns = {'POPESTIMATE2014':'2014'})

# %%
 df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 1      0    1        3978070            3978090          3957888
# 2      0    2        4096929            4096939          4090862
# 3      0    3        4119040            4119051          4111920
# 4      0    4        4063170            4063186          4077551
# ..   ...  ...            ...                ...              ...
# 301    2   97          53582              53605            54118
# 302    2   98          36641              36675            37532
# 303    2   99          26193              26214            26074
# 304    2  100          44202              44246            45058
# 305    2  999      156964212          156969328        157258820
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013       2014  \
# 0            3963087          3926540          3931141    3949775
# 1            3966551          3977939          3942872    3949776
# 2            3971565          3980095          3992720    3959664
# 3            4102470          3983157          3992734    4007079
# 4            4122294          4112849          3994449    4005716
# ..               ...              ...              ...        ...
# 301            57159            59533            61255      62779
# 302            40116            42857            44359      46208
# 303            27030            29320            31112      32517
# 304            47556            50661            53902      58008
# 305        158427085        159581546        160720625  161952064
#
#      POPESTIMATE2015
# 0            3978038
# 1            3968564
# 2            3966583
# 3            3974061
# 4            4020035
# ..               ...
# 301            69285
# 302            47272
# 303            34064
# 304            61886
# 305        163189523
#
# [306 rows x 10 columns]

# %%
df = df.rename(columns = {'POPESTIMATE2010':'2010'})

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 301    2   97          53582              53605      54118            57159
# 302    2   98          36641              36675      37532            40116
# 303    2   99          26193              26214      26074            27030
# 304    2  100          44202              44246      45058            47556
# 305    2  999      156964212          156969328  157258820        158427085
#
#      POPESTIMATE2012  POPESTIMATE2013       2014  POPESTIMATE2015
# 0            3926540          3931141    3949775          3978038
# 1            3977939          3942872    3949776          3968564
# 2            3980095          3992720    3959664          3966583
# 3            3983157          3992734    4007079          3974061
# 4            4112849          3994449    4005716          4020035
# ..               ...              ...        ...              ...
# 301            59533            61255      62779            69285
# 302            42857            44359      46208            47272
# 303            29320            31112      32517            34064
# 304            50661            53902      58008            61886
# 305        159581546        160720625  161952064        163189523
#
# [306 rows x 10 columns]

# %%
df.head(10)
# Out:
#    SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0    0    0        3944153            3944160  3951330          3963087
# 1    0    1        3978070            3978090  3957888          3966551
# 2    0    2        4096929            4096939  4090862          3971565
# 3    0    3        4119040            4119051  4111920          4102470
# 4    0    4        4063170            4063186  4077551          4122294
# 5    0    5        4056858            4056872  4064653          4087709
# 6    0    6        4066381            4066412  4073013          4074993
# 7    0    7        4030579            4030594  4043046          4083225
# 8    0    8        4046486            4046497  4025604          4053203
# 9    0    9        4148353            4148369  4125415          4035710
#
#    POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0          3926540          3931141  3949775          3978038
# 1          3977939          3942872  3949776          3968564
# 2          3980095          3992720  3959664          3966583
# 3          3983157          3992734  4007079          3974061
# 4          4112849          3994449  4005716          4020035
# 5          4132242          4123626  4006900          4018158
# 6          4097605          4142916  4135930          4019207
# 7          4084913          4108349  4155326          4148360
# 8          4093177          4095711  4120903          4167887
# 9          4063152          4104072  4108349          4133564

# %%
df.loc[15]
# Out:
# SEX                        0
# AGE                       15
# CENSUS2010POP        4242820
# ESTIMATESBASE2010    4242946
# 2010                 4231002
# POPESTIMATE2011      4158941
# POPESTIMATE2012      4144019
# POPESTIMATE2013      4149121
# 2014                 4164796
# POPESTIMATE2015      4249742
# Name: 15, dtype: int64

# %%
df.loc[22]
# Out:
# SEX                        0
# AGE                       22
# CENSUS2010POP        4264642
# ESTIMATESBASE2010    4264946
# 2010                 4287005
# POPESTIMATE2011      4415300
# POPESTIMATE2012      4628459
# POPESTIMATE2013      4665965
# 2014                 4615729
# POPESTIMATE2015      4529472
# Name: 22, dtype: int64

# %%
df.iloc[15:23:7]
# Out:
#     SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 15    0   15        4242820            4242946  4231002          4158941
# 22    0   22        4264642            4264946  4287005          4415300
#
#     POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 15          4144019          4149121  4164796          4249742
# 22          4628459          4665965  4615729          4529472

# %%
df['AGE']
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 301     97
# 302     98
# 303     99
# 304    100
# 305    999
# Name: AGE, Length: 306, dtype: int64

# %%
df['AGE'].plot()
# Out:
# <Axes: >

# %%
for i in df['AGE']:
    
    if i>60:
        print(i)
# Out:
# 61
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 999
# 61
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 999
# 61
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 999

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 301    2   97          53582              53605      54118            57159
# 302    2   98          36641              36675      37532            40116
# 303    2   99          26193              26214      26074            27030
# 304    2  100          44202              44246      45058            47556
# 305    2  999      156964212          156969328  157258820        158427085
#
#      POPESTIMATE2012  POPESTIMATE2013       2014  POPESTIMATE2015
# 0            3926540          3931141    3949775          3978038
# 1            3977939          3942872    3949776          3968564
# 2            3980095          3992720    3959664          3966583
# 3            3983157          3992734    4007079          3974061
# 4            4112849          3994449    4005716          4020035
# ..               ...              ...        ...              ...
# 301            59533            61255      62779            69285
# 302            42857            44359      46208            47272
# 303            29320            31112      32517            34064
# 304            50661            53902      58008            61886
# 305        159581546        160720625  161952064        163189523
#
# [306 rows x 10 columns]

# %%
df[df['AGE']==999]
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 101    0  999      308745538          308758105  309346863        311718857
# 203    1  999      151781326          151788777  152088043        153291772
# 305    2  999      156964212          156969328  157258820        158427085
#
#      POPESTIMATE2012  POPESTIMATE2013       2014  POPESTIMATE2015
# 101        314102623        316427395  318907401        321418820
# 203        154521077        155706770  156955337        158229297
# 305        159581546        160720625  161952064        163189523

# %%
df = df.drop(index=101)

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 301    2   97          53582              53605      54118            57159
# 302    2   98          36641              36675      37532            40116
# 303    2   99          26193              26214      26074            27030
# 304    2  100          44202              44246      45058            47556
# 305    2  999      156964212          156969328  157258820        158427085
#
#      POPESTIMATE2012  POPESTIMATE2013       2014  POPESTIMATE2015
# 0            3926540          3931141    3949775          3978038
# 1            3977939          3942872    3949776          3968564
# 2            3980095          3992720    3959664          3966583
# 3            3983157          3992734    4007079          3974061
# 4            4112849          3994449    4005716          4020035
# ..               ...              ...        ...              ...
# 301            59533            61255      62779            69285
# 302            42857            44359      46208            47272
# 303            29320            31112      32517            34064
# 304            50661            53902      58008            61886
# 305        159581546        160720625  161952064        163189523
#
# [305 rows x 10 columns]

# %%
df = df.drop(index = 203)

# %%
df = df.drop(index = 305)

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 1      0    1        3978070            3978090  3957888          3966551
# 2      0    2        4096929            4096939  4090862          3971565
# 3      0    3        4119040            4119051  4111920          4102470
# 4      0    4        4063170            4063186  4077551          4122294
# ..   ...  ...            ...                ...      ...              ...
# 300    2   96          73799              73856    75139            77460
# 301    2   97          53582              53605    54118            57159
# 302    2   98          36641              36675    37532            40116
# 303    2   99          26193              26214    26074            27030
# 304    2  100          44202              44246    45058            47556
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 1            3977939          3942872  3949776          3968564
# 2            3980095          3992720  3959664          3966583
# 3            3983157          3992734  4007079          3974061
# 4            4112849          3994449  4005716          4020035
# ..               ...              ...      ...              ...
# 300            79970            81490    89432            90302
# 301            59533            61255    62779            69285
# 302            42857            44359    46208            47272
# 303            29320            31112    32517            34064
# 304            50661            53902    58008            61886
#
# [303 rows x 10 columns]

# %%
df['AGE'].plot()
# Out:
# <Axes: >

# %%
df[df['AGE']==999]
# Out:
# Empty DataFrame
# Columns: [SEX, AGE, CENSUS2010POP, ESTIMATESBASE2010, 2010, POPESTIMATE2011, POPESTIMATE2012, POPESTIMATE2013, 2014, POPESTIMATE2015]
# Index: []

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 1      0    1        3978070            3978090  3957888          3966551
# 2      0    2        4096929            4096939  4090862          3971565
# 3      0    3        4119040            4119051  4111920          4102470
# 4      0    4        4063170            4063186  4077551          4122294
# ..   ...  ...            ...                ...      ...              ...
# 300    2   96          73799              73856    75139            77460
# 301    2   97          53582              53605    54118            57159
# 302    2   98          36641              36675    37532            40116
# 303    2   99          26193              26214    26074            27030
# 304    2  100          44202              44246    45058            47556
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 1            3977939          3942872  3949776          3968564
# 2            3980095          3992720  3959664          3966583
# 3            3983157          3992734  4007079          3974061
# 4            4112849          3994449  4005716          4020035
# ..               ...              ...      ...              ...
# 300            79970            81490    89432            90302
# 301            59533            61255    62779            69285
# 302            42857            44359    46208            47272
# 303            29320            31112    32517            34064
# 304            50661            53902    58008            61886
#
# [303 rows x 10 columns]

# %%
df.plot(kind = "scatter",x ='SEX',y='AGE')
# Out:
# <Axes: xlabel='SEX', ylabel='AGE'>

# %%
df.isnull().sum()
# Out:
# SEX                  0
# AGE                  0
# CENSUS2010POP        0
# ESTIMATESBASE2010    0
# 2010                 0
# POPESTIMATE2011      0
# POPESTIMATE2012      0
# POPESTIMATE2013      0
# 2014                 0
# POPESTIMATE2015      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 1      0    1        3978070            3978090  3957888          3966551
# 2      0    2        4096929            4096939  4090862          3971565
# 3      0    3        4119040            4119051  4111920          4102470
# 4      0    4        4063170            4063186  4077551          4122294
# ..   ...  ...            ...                ...      ...              ...
# 300    2   96          73799              73856    75139            77460
# 301    2   97          53582              53605    54118            57159
# 302    2   98          36641              36675    37532            40116
# 303    2   99          26193              26214    26074            27030
# 304    2  100          44202              44246    45058            47556
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 1            3977939          3942872  3949776          3968564
# 2            3980095          3992720  3959664          3966583
# 3            3983157          3992734  4007079          3974061
# 4            4112849          3994449  4005716          4020035
# ..               ...              ...      ...              ...
# 300            79970            81490    89432            90302
# 301            59533            61255    62779            69285
# 302            42857            44359    46208            47272
# 303            29320            31112    32517            34064
# 304            50661            53902    58008            61886
#
# [303 rows x 10 columns]

# %%
tf = df[df['AGE']==0]
arr = []
for i in range(6):
    val = tf.iloc[0,4+i]
    val1 = tf.iloc[1,4+i]
    arr.append(val1/val)

# %%
print(arr)
# Out:
# [0.5108204073058945, 0.5118300456184788, 0.5113196350985855, 0.5111818680632417, 0.5115040730168174, 0.511592398061557]

# %%
plt.plot(arr)

# %%
tf
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 102    1    0        2014276            2014278  2018420          2028427
# 204    2    0        1929877            1929882  1932910          1934660
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 102          2007717          2009528  2020326          2035134
# 204          1918823          1921613  1929449          1942904

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 1      0    1        3978070            3978090  3957888          3966551
# 2      0    2        4096929            4096939  4090862          3971565
# 3      0    3        4119040            4119051  4111920          4102470
# 4      0    4        4063170            4063186  4077551          4122294
# ..   ...  ...            ...                ...      ...              ...
# 300    2   96          73799              73856    75139            77460
# 301    2   97          53582              53605    54118            57159
# 302    2   98          36641              36675    37532            40116
# 303    2   99          26193              26214    26074            27030
# 304    2  100          44202              44246    45058            47556
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 1            3977939          3942872  3949776          3968564
# 2            3980095          3992720  3959664          3966583
# 3            3983157          3992734  4007079          3974061
# 4            4112849          3994449  4005716          4020035
# ..               ...              ...      ...              ...
# 300            79970            81490    89432            90302
# 301            59533            61255    62779            69285
# 302            42857            44359    46208            47272
# 303            29320            31112    32517            34064
# 304            50661            53902    58008            61886
#
# [303 rows x 10 columns]

# %%
df.iloc[100]
# Out:
# SEX                      0
# AGE                    100
# CENSUS2010POP        53364
# ESTIMATESBASE2010    53412
# 2010                 54410
# POPESTIMATE2011      57702
# POPESTIMATE2012      61821
# POPESTIMATE2013      66189
# 2014                 71626
# POPESTIMATE2015      76974
# Name: 100, dtype: int64

# %%
df.loc[:100]
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 1      0    1        3978070            3978090  3957888          3966551
# 2      0    2        4096929            4096939  4090862          3971565
# 3      0    3        4119040            4119051  4111920          4102470
# 4      0    4        4063170            4063186  4077551          4122294
# ..   ...  ...            ...                ...      ...              ...
# 96     0   96          95223              95288    97161           101261
# 97     0   97          68138              68168    68893            73274
# 98     0   98          45900              45938    47037            50670
# 99     0   99          32266              32289    32178            33636
# 100    0  100          53364              53412    54410            57702
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 1            3977939          3942872  3949776          3968564
# 2            3980095          3992720  3959664          3966583
# 3            3983157          3992734  4007079          3974061
# 4            4112849          3994449  4005716          4020035
# ..               ...              ...      ...              ...
# 96            105420           108964   120485           122887
# 97             77156            79953    83089            92377
# 98             54509            57015    59726            61991
# 99             36779            39271    41468            43641
# 100            61821            66189    71626            76974
#
# [101 rows x 10 columns]

# %%
df.loc[102:202]
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 102    1    0        2014276            2014278  2018420          2028427
# 103    1    1        2030853            2030861  2020332          2025522
# 104    1    2        2092198            2092202  2088685          2026973
# 105    1    3        2104550            2104555  2101272          2094296
# 106    1    4        2077550            2077556  2084312          2106323
# ..   ...  ...            ...                ...      ...              ...
# 198    1   96          21424              21432    22022            23801
# 199    1   97          14556              14563    14775            16115
# 200    1   98           9259               9263     9505            10554
# 201    1   99           6073               6075     6104             6606
# 202    1  100           9162               9166     9352            10146
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 102          2007717          2009528  2020326          2035134
# 103          2035460          2015470  2018401          2029295
# 104          2032095          2042649  2023673          2026604
# 105          2032529          2038176  2049596          2030644
# 106          2099309          2038023  2044517          2055924
# ..               ...              ...      ...              ...
# 198            25450            27474    31053            32585
# 199            17623            18698    20310            23092
# 200            11652            12656    13518            14719
# 201             7459             8159     8951             9577
# 202            11160            12287    13618            15088
#
# [101 rows x 10 columns]

# %%
df.loc[203:]
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 204    2    0        1929877            1929882  1932910          1934660
# 205    2    1        1947217            1947229  1937556          1941029
# 206    2    2        2004731            2004737  2002177          1944592
# 207    2    3        2014490            2014496  2010648          2008174
# 208    2    4        1985620            1985630  1993239          2015971
# ..   ...  ...            ...                ...      ...              ...
# 300    2   96          73799              73856    75139            77460
# 301    2   97          53582              53605    54118            57159
# 302    2   98          36641              36675    37532            40116
# 303    2   99          26193              26214    26074            27030
# 304    2  100          44202              44246    45058            47556
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 204          1918823          1921613  1929449          1942904
# 205          1942479          1927402  1931375          1939269
# 206          1948000          1950071  1935991          1939979
# 207          1950628          1954558  1957483          1943417
# 208          2013540          1956426  1961199          1964111
# ..               ...              ...      ...              ...
# 300            79970            81490    89432            90302
# 301            59533            61255    62779            69285
# 302            42857            44359    46208            47272
# 303            29320            31112    32517            34064
# 304            50661            53902    58008            61886
#
# [101 rows x 10 columns]

# %%
df1 = df.loc[:100]
df2 = df.loc[102:202]
df3 = df.loc[203:]

# %%
df1
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 1      0    1        3978070            3978090  3957888          3966551
# 2      0    2        4096929            4096939  4090862          3971565
# 3      0    3        4119040            4119051  4111920          4102470
# 4      0    4        4063170            4063186  4077551          4122294
# ..   ...  ...            ...                ...      ...              ...
# 96     0   96          95223              95288    97161           101261
# 97     0   97          68138              68168    68893            73274
# 98     0   98          45900              45938    47037            50670
# 99     0   99          32266              32289    32178            33636
# 100    0  100          53364              53412    54410            57702
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 1            3977939          3942872  3949776          3968564
# 2            3980095          3992720  3959664          3966583
# 3            3983157          3992734  4007079          3974061
# 4            4112849          3994449  4005716          4020035
# ..               ...              ...      ...              ...
# 96            105420           108964   120485           122887
# 97             77156            79953    83089            92377
# 98             54509            57015    59726            61991
# 99             36779            39271    41468            43641
# 100            61821            66189    71626            76974
#
# [101 rows x 10 columns]

# %%
df2
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 102    1    0        2014276            2014278  2018420          2028427
# 103    1    1        2030853            2030861  2020332          2025522
# 104    1    2        2092198            2092202  2088685          2026973
# 105    1    3        2104550            2104555  2101272          2094296
# 106    1    4        2077550            2077556  2084312          2106323
# ..   ...  ...            ...                ...      ...              ...
# 198    1   96          21424              21432    22022            23801
# 199    1   97          14556              14563    14775            16115
# 200    1   98           9259               9263     9505            10554
# 201    1   99           6073               6075     6104             6606
# 202    1  100           9162               9166     9352            10146
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 102          2007717          2009528  2020326          2035134
# 103          2035460          2015470  2018401          2029295
# 104          2032095          2042649  2023673          2026604
# 105          2032529          2038176  2049596          2030644
# 106          2099309          2038023  2044517          2055924
# ..               ...              ...      ...              ...
# 198            25450            27474    31053            32585
# 199            17623            18698    20310            23092
# 200            11652            12656    13518            14719
# 201             7459             8159     8951             9577
# 202            11160            12287    13618            15088
#
# [101 rows x 10 columns]

# %%
df3
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 204    2    0        1929877            1929882  1932910          1934660
# 205    2    1        1947217            1947229  1937556          1941029
# 206    2    2        2004731            2004737  2002177          1944592
# 207    2    3        2014490            2014496  2010648          2008174
# 208    2    4        1985620            1985630  1993239          2015971
# ..   ...  ...            ...                ...      ...              ...
# 300    2   96          73799              73856    75139            77460
# 301    2   97          53582              53605    54118            57159
# 302    2   98          36641              36675    37532            40116
# 303    2   99          26193              26214    26074            27030
# 304    2  100          44202              44246    45058            47556
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 204          1918823          1921613  1929449          1942904
# 205          1942479          1927402  1931375          1939269
# 206          1948000          1950071  1935991          1939979
# 207          1950628          1954558  1957483          1943417
# 208          2013540          1956426  1961199          1964111
# ..               ...              ...      ...              ...
# 300            79970            81490    89432            90302
# 301            59533            61255    62779            69285
# 302            42857            44359    46208            47272
# 303            29320            31112    32517            34064
# 304            50661            53902    58008            61886
#
# [101 rows x 10 columns]

# %%
s = df1.iloc[:,4].sum()

# %%
print(s)
# Out:
# 309346863

# %%
df1
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 1      0    1        3978070            3978090  3957888          3966551
# 2      0    2        4096929            4096939  4090862          3971565
# 3      0    3        4119040            4119051  4111920          4102470
# 4      0    4        4063170            4063186  4077551          4122294
# ..   ...  ...            ...                ...      ...              ...
# 96     0   96          95223              95288    97161           101261
# 97     0   97          68138              68168    68893            73274
# 98     0   98          45900              45938    47037            50670
# 99     0   99          32266              32289    32178            33636
# 100    0  100          53364              53412    54410            57702
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 1            3977939          3942872  3949776          3968564
# 2            3980095          3992720  3959664          3966583
# 3            3983157          3992734  4007079          3974061
# 4            4112849          3994449  4005716          4020035
# ..               ...              ...      ...              ...
# 96            105420           108964   120485           122887
# 97             77156            79953    83089            92377
# 98             54509            57015    59726            61991
# 99             36779            39271    41468            43641
# 100            61821            66189    71626            76974
#
# [101 rows x 10 columns]

# %%
df2
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 102    1    0        2014276            2014278  2018420          2028427
# 103    1    1        2030853            2030861  2020332          2025522
# 104    1    2        2092198            2092202  2088685          2026973
# 105    1    3        2104550            2104555  2101272          2094296
# 106    1    4        2077550            2077556  2084312          2106323
# ..   ...  ...            ...                ...      ...              ...
# 198    1   96          21424              21432    22022            23801
# 199    1   97          14556              14563    14775            16115
# 200    1   98           9259               9263     9505            10554
# 201    1   99           6073               6075     6104             6606
# 202    1  100           9162               9166     9352            10146
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 102          2007717          2009528  2020326          2035134
# 103          2035460          2015470  2018401          2029295
# 104          2032095          2042649  2023673          2026604
# 105          2032529          2038176  2049596          2030644
# 106          2099309          2038023  2044517          2055924
# ..               ...              ...      ...              ...
# 198            25450            27474    31053            32585
# 199            17623            18698    20310            23092
# 200            11652            12656    13518            14719
# 201             7459             8159     8951             9577
# 202            11160            12287    13618            15088
#
# [101 rows x 10 columns]

# %%
a = df1.values
print(a[:,4:])
# Out:
# [[3951330 3963087 3926540 3931141 3949775 3978038]
#  [3957888 3966551 3977939 3942872 3949776 3968564]
#  [4090862 3971565 3980095 3992720 3959664 3966583]
#  [4111920 4102470 3983157 3992734 4007079 3974061]
#  [4077551 4122294 4112849 3994449 4005716 4020035]
#  [4064653 4087709 4132242 4123626 4006900 4018158]
#  [4073013 4074993 4097605 4142916 4135930 4019207]
#  [4043046 4083225 4084913 4108349 4155326 4148360]
#  [4025604 4053203 4093177 4095711 4120903 4167887]
#  [4125415 4035710 4063152 4104072 4108349 4133564]
#  [4187062 4135613 4045779 4074111 4116942 4121289]
#  [4115511 4197472 4146000 4057152 4087402 4130328]
#  [4113279 4126117 4208009 4157476 4070682 4101021]
#  [4119666 4124219 4136683 4219594 4171030 4084306]
#  [4145614 4131501 4135460 4148966 4233839 4185386]
#  [4231002 4158941 4144019 4149121 4164796 4249742]
#  [4313252 4247444 4174379 4160892 4168559 4184296]
#  [4376367 4334976 4268074 4196841 4186513 4194286]
#  [4491005 4402578 4359870 4295311 4227920 4217995]
#  [4571411 4520659 4430212 4388983 4329038 4262584]
#  [4568517 4600425 4549989 4458717 4421330 4363440]
#  [4387956 4596166 4632892 4580130 4492373 4456790]
#  [4287005 4415300 4628459 4665965 4615729 4529472]
#  [4217228 4314771 4446836 4660804 4702156 4652266]
#  [4243602 4244555 4345405 4477806 4695411 4737345]
#  [4289428 4269914 4274505 4375341 4511370 4729564]
#  [4160806 4313743 4298276 4303348 4408043 4544416]
#  [4237026 4183423 4340058 4325959 4334806 4439766]
#  [4247541 4258087 4207400 4364997 4355240 4364669]
#  [4210286 4266544 4280262 4230388 4391788 4383139]
#  [4304239 4227388 4286351 4301333 4255334 4417209]
#  [4042516 4319518 4244957 4304735 4323217 4278233]
#  [3967602 4055945 4335012 4261440 4323951 4343614]
#  [3933581 3979999 4069367 4349412 4278664 4341754]
#  [3822189 3944594 3992461 4081963 4364748 4294838]
#  [3948335 3832507 3955953 4004249 4095782 4379404]
#  [3830199 3957062 3842465 3965855 4016711 4108775]
#  [3896766 3837775 3965930 3851572 3976750 4028403]
#  [4080228 3903219 3845592 3973859 3861636 3987141]
#  [4324463 4085665 3909562 3852500 3982507 3870862]
#  [4387480 4327667 4090348 3914669 3859395 3989839]
#  [4163478 4388870 4330376 4093892 3919810 3865228]
#  [4082712 4163973 4390089 4332009 4097698 3924258]
#  [4093844 4082407 4164092 4390066 4333850 4100708]
#  [4178508 4092574 4081644 4163434 4390283 4335165]
#  [4438559 4175437 4090390 4079456 4162629 4389345]
#  [4529716 4433561 4171181 4086735 4077151 4160573]
#  [4535473 4522447 4427056 4165790 4082883 4073685]
#  [4534663 4525970 4513628 4418987 4159738 4077689]
#  [4599098 4523285 4515219 4503312 4410246 4152552]
#  [4646231 4585687 4510749 4502956 4492407 4400288]
#  [4498974 4631123 4570562 4496079 4489393 4479664]
#  [4480584 4482225 4613728 4553156 4480188 4474344]
#  [4439403 4461939 4463445 4594750 4535430 4463494]
#  [4288447 4418949 4441616 4443259 4574760 4516527]
#  [4258970 4266666 4396744 4419516 4421856 4553385]
#  [4093136 4236030 4243306 4372503 4395949 4399120]
#  [3946518 4069019 4211105 4218041 4347023 4371245]
#  [3802447 3921219 4043361 4184031 4191360 4320522]
#  [3694254 3776077 3894584 4015151 4155521 4163670]
#  [3616721 3667096 3748195 3865421 3985598 4125792]
#  [3520109 3588440 3637901 3717783 3834367 3954601]
#  [3495059 3489560 3557636 3605696 3685282 3801935]
#  [3652167 3461369 3456712 3523650 3571610 3651393]
#  [2706055 3614375 3425798 3420461 3487559 3536156]
#  [2678525 2675911 3574749 3387120 3382824 3450043]
#  [2621335 2646364 2644042 3531521 3347060 3344134]
#  [2693707 2586302 2612002 2609390 3485241 3304187]
#  [2359816 2654106 2548669 2574501 2572359 3436357]
#  [2167830 2321925 2612071 2507744 2534295 2532747]
#  [2062577 2129707 2282127 2566440 2465438 2492490]
#  [1953607 2022972 2090119 2238833 2519705 2421191]
#  [1883820 1912417 1981694 2046698 2193945 2469605]
#  [1750304 1840167 1869373 1936421 2001700 2146052]
#  [1685995 1705634 1794659 1822287 1889513 1953711]
#  [1631878 1638711 1659254 1745063 1773756 1839823]
#  [1481680 1581369 1589520 1608544 1693674 1722041]
#  [1449173 1430861 1529021 1535823 1556104 1639085]
#  [1402182 1394591 1378355 1472041 1480611 1500813]
#  [1354912 1343720 1338220 1321253 1413193 1422071]
#  [1319725 1292451 1283388 1277015 1262537 1351196]
#  [1212603 1252491 1228132 1218174 1214357 1201044]
#  [1158351 1143940 1183585 1158932 1151677 1148948]
#  [1081440 1085378 1073723 1109508 1088601 1082562]
#  [ 987023 1005421 1011083  998540 1034369 1015591]
#  [ 915013  909434  928705  932175  922947  957023]
#  [ 821549  834977  831965  848046  853723  846081]
#  [ 721196  741551  756097  751513  768676  774639]
#  [ 636657  643266  663786  675235  673402  689755]
#  [ 546193  560099  568661  585180  597828  596847]
#  [ 448324  473878  487975  494402  511074  523034]
#  [ 344442  382670  406898  417343  425314  440318]
#  [ 288841  289272  322982  342490  352912  360659]
#  [ 219064  238076  240184  266668  284885  293806]
#  [ 170775  176696  193865  194920  217328  233118]
#  [ 131077  135065  140683  153970  156288  174011]
#  [  97161  101261  105420  108964  120485  122887]
#  [  68893   73274   77156   79953   83089   92377]
#  [  47037   50670   54509   57015   59726   61991]
#  [  32178   33636   36779   39271   41468   43641]
#  [  54410   57702   61821   66189   71626   76974]]

# %%
ratio = pd.DataFrame(df1.values[:,4:]/df2.values[:,4:],columns = df.columns[4:])
ratio
# Out:
#          2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013      2014  \
# 0    1.957635         1.953774         1.955724         1.956251  1.955019
# 1    1.959029         1.958286         1.954319         1.956304  1.956884
# 2    1.958583         1.959358         1.958617         1.954677  1.956672
# 3    1.956872         1.958878         1.959705         1.958974  1.955058
# 4    1.956305         1.957104         1.959144         1.959963  1.959248
# ..        ...              ...              ...              ...       ...
# 96   4.411997         4.254485         4.142240         3.966077  3.879979
# 97   4.662809         4.546944         4.378142         4.276019  4.091039
# 98   4.948659         4.801023         4.678081         4.504978  4.418257
# 99   5.271625         5.091735         4.930822         4.813212  4.632778
# 100  5.818007         5.687167         5.539516         5.386913  5.259656
#
#      POPESTIMATE2015
# 0           1.954681
# 1           1.955637
# 2           1.957256
# 3           1.957045
# 4           1.955342
# ..               ...
# 96          3.771275
# 97          4.000390
# 98          4.211631
# 99          4.556855
# 100         5.101670
#
# [101 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [30, 25, 20, 25]  # Proportions or percentages
colors = ['red', 'blue', 'green', 'orange']
explode = (0.1, 0, 0, 0)  # Explode a slice (create some distance)

# Create a pie chart
plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Equal aspect ratio ensures the pie is circular

# Add a title
plt.title('Sample Pie Chart')

# Show the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels,autopct = "%d%%")
plt.legend(title = "Four Fruits:")
plt.show()

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py
  
# np.random generates different random numbers
# whenever the code is executed
# Note: When you execute the same code 
  
# Random data points generated
data_points = np.random.normal(0, 1, 100)    
print(data_points)
sm.qqplot(data_points, line ='45')
py.show()
# Out:
# [ 0.46313033  0.27909576  0.33890413  2.02104356 -0.46886419 -2.20144129
#   0.1993002  -0.05060354 -0.51751904 -0.97882986 -0.43918952  0.18133843
#  -0.5028167   2.41245368 -0.96050438 -0.79311736 -2.28862004  0.25148442
#  -2.01640663 -0.53945463 -0.27567053 -0.70972797  1.73887268  0.99439439
#   1.31913688 -0.88241882  1.12859406  0.49600095  0.77140595  1.02943883
#  -0.90876325 -0.42431762  0.86259601 -2.65561909  1.51332808  0.55313206
#  -0.04570396  0.22050766 -1.02993528 -0.34994336  1.10028434  1.29802197
#   2.69622405 -0.07392467 -0.65855297 -0.51423397 -1.01804188 -0.07785476
#   0.38273243 -0.03424228  1.09634685 -0.2342158  -0.34745065 -0.58126848
#  -1.63263453 -1.56776772 -1.17915793  1.30142807  0.89526027  1.37496407
#  -1.33221165 -1.96862469 -0.66005632  0.17581895  0.49869027  1.04797216
#   0.28427967  1.74266878 -0.22260568 -0.91307922 -1.68121822 -0.88897136
#   0.24211796 -0.88872026  0.93674246  1.41232771 -2.36958691  0.8640523
#  -2.23960406  0.40149906  1.22487056  0.06485611 -1.27968917 -0.5854312
#  -0.26164545 -0.18224478 -0.20289684 -0.10988278  0.21348005 -1.20857365
#  -0.24201983  1.51826117 -0.38464542 -0.44383609  1.0781973  -2.55918467
#   1.1813786  -0.63190376  0.16392857  0.09632136]
