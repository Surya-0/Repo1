# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Bar Plot

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]

col= ["blue","black","gold","orange"]
plt.bar(x,y,width=0.2,color = col,align="center",edgecolor = "red",linewidth = 2,linestyle = "dotted",alpha = 0.7,label = "titan") # alpha parameter is for color of the fillings inside

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")
plt.legend(loc= "best")
plt.show()

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z= [20,30,40,50]
p = np.arange(len(x))  
width = 0.2
p1 = [j+width for j in p]

plt.bar(p,y,width,color = "red",label = "titan") # alpha parameter is for color of the fillings inside
plt.bar(p1,z,width,color = "aqua",label = "titan1")

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")

plt.xticks(p+width/2,x,rotation = 20)
plt.legend()
plt.show()
print(p)
print(p1)
# Out:
# [0 1 2 3]
# [0.2, 1.2, 2.2, 3.2]

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
z= [20,30,40,50]
p = np.arange(len(x))  
width = 0.2
p1 = [j+width for j in p]

plt.barh(x,y,width,color = "red",label = "titan") # alpha parameter is for color of the fillings inside
plt.barh(x,z,width,color = "aqua",label = "titan1")

plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")


plt.legend()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
day = [1,2,3,4,5,6,7]
num = [2,3,1,4,5,3,6]
col = ['blue', 'red', 'green','magenta','cyan','purple','black']
plt.scatter(day,num,c = col,s = 30)
plt.xlabel("Day")
plt.ylabel("Number")
plt.show()

# %%
day = [1,2,3,4,5,6,7]
num = [2,3,1,4,5,3,6]
col = ['blue', 'red', 'green','magenta','cyan','purple','black']
plt.scatter(day,num,s = 50,c=col,alpha=0.6,marker="*",edgecolors="black",linewidth=2,cmap="viridis")
t=plt.colorbar()
t.set_label("Color Bar")
plt.xlabel("Day")
plt.ylabel("Number")
plt.show()
# Out:
# /var/folders/21/yhy2dhmx219b7cbcq243hmwc0000gn/T/ipykernel_43762/1106043664.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(day,num,s = 50,c=col,alpha=0.6,marker="*",edgecolors="black",linewidth=2,cmap="viridis")

# %% [markdown]
# ## Histogram Plot

# %%
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [37 14 34 53 45 19 46 13 27 58 38 53 58 45 51 30 49 34 55 40 42 53 35 22
#  46 16 58 34 23 56 53 44 28 14 53 34 50 44 52 19 52 37 49 54 10 29 24 57
#  27 44]

# %%
y=[]
for i in x:
    y.append(i)

y=np.array(y)
print(y)
# Out:
# [37 14 34 53 45 19 46 13 27 58 38 53 58 45 51 30 49 34 55 40 42 53 35 22
#  46 16 58 34 23 56 53 44 28 14 53 34 50 44 52 19 52 37 49 54 10 29 24 57
#  27 44]

# %%
plt.hist(y,edgecolor="black",bins =[10,20,30,40,50,60],align='mid',histtype='bar',orientation='vertical',rwidth=1,log=True,label="python")
plt.axvline(45,color="green",label = "Axis")

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.legend()
plt.show()

# %%
plt.hist(y,edgecolor="black",range=(0,100))

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.show()

# %%
plt.hist(y,edgecolor="black",range=(0,100),cumulative=-1)

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("Number")
plt.show()
