# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Bar Plot

# %%
x = ["python","c","c++","java"]
y = [85,70,60,82]
col= ["blue","black","gold","orange"]
plt.bar(x,y,width=0.5,color = col,align="center",edgecolor = "red",linewidth = 2,linestyle = "dotted",alpha = 0.7,label = "titan") # alpha parameter is for color of the fillings inside
plt.xlabel("language",fontsize=10)
plt.ylabel("number",fontsize=12)
plt.title("Language Usage Comparison")
plt.legend()
plt.show()
