# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import seaborn as sns

# %%
data = [['apple',10,240],['orange',15,150],['grapes',14,80],['pineapple',10,70]]
df1 = pd.DataFrame(data,columns=['Fruit_name','Quantity','Unit_price'])
df1
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70

# %%
quant = []
quant = df1['Quantity']
quant = np.array(quant)
Fruits = []
Fruits = df1['Fruit_name']
Fruits = np.array(Fruits)
print(Fruits)
print(quant)
# Out:
# ['apple' 'orange' 'grapes' 'pineapple']
# [10 15 14 10]

# %%
df1.describe()
# Out:
#         Quantity  Unit_price
# count   4.000000    4.000000
# mean   12.250000  135.000000
# std     2.629956   78.528127
# min    10.000000   70.000000
# 25%    10.000000   77.500000
# 50%    12.000000  115.000000
# 75%    14.250000  172.500000
# max    15.000000  240.000000

# %%
mpl.bar(Fruits,quant)
mpl.xlabel('Fruits')
mpl.ylabel('Unit_price')
mpl.title('Bar plot example')
mpl.show()

# %%
# Loading the Data
iris = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ["sepal_length","sepal_width","petal_length","petal_width","class"]
df_flowers = pd.read_csv(iris,sep=',',names =names) 
df_flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_flowers.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
# Load a sample dataset
# data = sns.load_dataset("df_flowers")

# Create a pair plot
sns.pairplot(df_flowers,hue="class")

# Show the plot
mpl.show()

# %%
df_flowers.describe()
df_flowers.info()
df_flowers.duplicated().sum()
df_flowers.notnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# class           150
# dtype: int64

# %%
df_flowers.iloc[5]
# Out:
# sepal_length            5.4
# sepal_width             3.9
# petal_length            1.7
# petal_width             0.4
# class           Iris-setosa
# Name: 5, dtype: object

# %%
titanic_data = sns.load_dataset("titanic")

# Display the first few rows of the dataset
print(titanic_data.head())

# Create a bar plot of passenger class distribution
sns.countplot(x="class", data=titanic_data)

# Add labels and title
mpl.xlabel("Passenger Class")
mpl.ylabel("Number of Passengers")
mpl.title("Passenger Class Distribution")

# Show the plot
mpl.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data = df1.iloc[:,1:4]
print(data)
# Out:
#    Quantity  Unit_price
# 0        10         240
# 1        15         150
# 2        14          80
# 3        10          70

# %%
df1.corr()
# Out:
# /var/folders/21/yhy2dhmx219b7cbcq243hmwc0000gn/T/ipykernel_68379/473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#             Quantity  Unit_price
# Quantity    1.000000   -0.234031
# Unit_price -0.234031    1.000000

# %%
df_flowers.plot()
df1.plot()
# Out:
# <Axes: >

# %%
df_flowers.plot()
# Out:
# <Axes: >

# %%
df_flowers.plot(x='sepal_length',y='sepal_width',kind='scatter',title='scatter_plot')
mpl.plot()
# Out:
# []

# %%
df_flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_flowers.shape[0]
# Out:
# 150
